# %% [markdown]
# ## Support Vector Regression Implementation

# %%
## Dataset -> tips dataset
import seaborn as sns
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
## Independent and dependent features
X = df[['tip', 'sex', 'smoker', 'day', 'time', 'size']]
y = df[['total_bill']]

# %%
## Train test split
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state = 10)

# %%
X_train.head()
# Out:
#       tip   sex smoker  day    time  size
# 58   1.76  Male    Yes  Sat  Dinner     2
# 1    1.66  Male     No  Sun  Dinner     3
# 2    3.50  Male     No  Sun  Dinner     3
# 68   2.01  Male     No  Sat  Dinner     2
# 184  3.00  Male    Yes  Sun  Dinner     2

# %% [markdown]
# ## Feature Encoding(Label Encoding and Onehot Encoding)
# ## For categories as smoker and sex we can change it into 0 and 1 so we can do it by label encoding
# ## For categories such as day we can't change it to 0 and 1 so we do onehot encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le1 = LabelEncoder()
le2 = LabelEncoder()
le3 = LabelEncoder()

# %%
X_train['sex'] = le1.fit_transform(X_train['sex'])
X_train['smoker'] = le2.fit_transform(X_train['smoker'])
X_train['time'] = le3.fit_transform(X_train['time'])

# %%
X_train.head()
# Out:
#       tip  sex  smoker  day  time  size
# 58   1.76    1       1  Sat     0     2
# 1    1.66    1       0  Sun     0     3
# 2    3.50    1       0  Sun     0     3
# 68   2.01    1       0  Sat     0     2
# 184  3.00    1       1  Sun     0     2

# %%
X_train.tail()
# Out:
#       tip  sex  smoker   day  time  size
# 64   2.64    1       0   Sat     0     3
# 15   3.92    1       0   Sun     0     2
# 228  2.72    1       0   Sat     0     2
# 125  4.20    0       0  Thur     1     6
# 9    3.23    1       0   Sun     0     2

# %%
X_test['sex'] = le1.transform(X_test['sex'])
X_test['smoker'] = le2.transform(X_test['smoker'])
X_test['time'] = le3.transform(X_test['time'])

# %%
X_test.head()
# Out:
#       tip  sex  smoker  day  time  size
# 162  2.00    0       0  Sun     0     3
# 60   3.21    1       1  Sat     0     2
# 61   2.00    1       1  Sat     0     2
# 63   3.76    1       1  Sat     0     4
# 69   2.09    1       1  Sat     0     2

# %%
# Onehot encoding for the day column --> ColumnTranformer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
ct = ColumnTransformer(transformers = [('onehot', OneHotEncoder(drop = 'first'),[3])], remainder ='passthrough')

# %%
import sys
import numpy
numpy.set_printoptions(threshold = sys.maxsize)
ct.fit_transform(X_train)
# Out:
# array([[ 1.  ,  0.  ,  0.  ,  1.76,  1.  ,  1.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  1.66,  1.  ,  0.  ,  0.  ,  3.  ],
#        [ 0.  ,  1.  ,  0.  ,  3.5 ,  1.  ,  0.  ,  0.  ,  3.  ],
#        [ 1.  ,  0.  ,  0.  ,  2.01,  1.  ,  0.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  3.  ,  1.  ,  1.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  4.  ,  0.  ,  1.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  5.2 ,  0.  ,  0.  ,  0.  ,  4.  ],
#        [ 0.  ,  0.  ,  1.  ,  4.  ,  1.  ,  1.  ,  1.  ,  4.  ],
#        [ 0.  ,  0.  ,  1.  ,  5.  ,  1.  ,  0.  ,  1.  ,  5.  ],
#        [ 1.  ,  0.  ,  0.  ,  3.  ,  0.  ,  0.  ,  0.  ,  2.  ],
#        [ 1.  ,  0.  ,  0.  ,  1.75,  1.  ,  0.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  ,  3.12,  1.  ,  0.  ,  0.  ,  4.  ],
#        [ 0.  ,  0.  ,  1.  ,  3.  ,  0.  ,  0.  ,  0.  ,  2.  ],
#        [ 1.  ,  0.  ,  0.  ,  5.  ,  1.  ,  0.  ,  0.  ,  3.  ],
# ...
